# %%
import pandas as pd
import os
from dotenv import load_dotenv

# %%
# Carregando as variáveis de ambiente
caminho_do_arquivo_env = r"C:\Users\Administrador\Documents\00-Projetos\Projeto_Python\Caminhos\caminho_VendasConsolidadas.env"
load_dotenv(dotenv_path=caminho_do_arquivo_env)

diretorio = os.getenv("DIRETORIO_ORIGEM")
pasta_destino = os.getenv("DIRETORIO_DESTINO")

# %%
# Consolidando os arquivos
dados = []
for arquivo in os.listdir(diretorio):
    if arquivo.lower().endswith('.xlsx'):
        caminho_arquivo = os.path.join(diretorio, arquivo)
        df = pd.read_excel(caminho_arquivo)
        dados.append(df)
consolidado = pd.concat(dados)

# %%
# Salvando o arquivo consolidado
nome_arquivo = 'Vendas_Totais.xlsx'
caminho_completo = os.path.join(pasta_destino, nome_arquivo)
if os.path.exists(caminho_completo):
    os.remove(caminho_completo)
consolidado.to_excel(caminho_completo, index=False)

print("Arquivo salvo com sucesso!")
# Out:
# Arquivo salvo com sucesso!
